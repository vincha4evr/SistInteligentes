# %% [markdown]
# <a href="https://colab.research.google.com/github/vincha4evr/SistInteligentes/blob/edward/Copia_de_Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Te damos la bienvenida a Colab</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>&#40;Novedad&#41; Prueba la API de Gemini</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API: Quickstart with Python</a></li>
#   <li><a href="https://colab.research.google.com/notebooks/snippets/gemini.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API code sample</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# Si ya conoces Colab, echa un vistazo a este vídeo para obtener información sobre las tablas interactivas, la vista del historial de código ejecutado y la paleta de comandos.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Miniatura de un vídeo que muestra tres funciones interesantes de Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %%
from google.colab import drive
drive.mount('/content/drive')


import csv
import pandas as pd
import numpy as np
import io
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.base import TransformerMixin
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Cargar datos de Fallecidos, Hospitalizados, Vacunados

df = pd.read_csv('/content/drive/MyDrive/MyDrive/pm27Sep2023.csv', encoding='utf8',sep=';' )
#df = pd.read_csv('/content/drive/MyDrive/fallecidos_covid_v3.csv',encoding='utf8')  # Roberto
#df = pd.read_csv('https://raw.githubusercontent.com/verajulio823/covid_fallecidos/master/fallecidos_covid_v4.csv', encoding='utf8')
df.head()
# Out:
# Mounted at /content/drive
#    FECHA_CORTE        UUID  FECHA_MUESTRA  EDAD       SEXO INSTITIUTCION  \
# 0     20230927  12978089.0       20200724    26   FEMENINO       PRIVADO
# 1     20230927  19929263.0       20200901    27  MASCULINO       PRIVADO
# 2     20230927  35827358.0       20200901    33  MASCULINO       PRIVADO
# 3     20230927  16667400.0       20200901    46  MASCULINO       PRIVADO
# 4     20230927  21465620.0       20200826    39  MASCULINO       PRIVADO
#
#    UBIGEO_PACIENTE DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE  \
# 0         140137.0                  LIMA               LIMA
# 1         250104.0               UCAYALI   CORONEL PORTILLO
# 2         140133.0                  LIMA               LIMA
# 3         240106.0                                   CALLAO
# 4         140140.0                  LIMA               LIMA
#
#         DISTRITO_PACIENTE DEPARTAMENTO_MUESTRA PROVINCIA_MUESTRA  \
# 0  SAN JUAN DE LURIGANCHO                 LIMA              LIMA
# 1              CAMPOVERDE                 LIMA              LIMA
# 2             JESUS MARIA                 LIMA              LIMA
# 3              VENTANILLA                 LIMA              LIMA
# 4               SAN BORJA                 LIMA              LIMA
#
#     DISTRITO_MUESTRA               TIPO_MUESTRA RESULTADO
# 0          SAN BORJA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1        JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 2        JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 3        JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 4  MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO

# %%
# Columnas a eliminar
DROP_COLUMNS = [
    'INSTITIUTCION',
    'UUID'


]


# Columnas categóricas a mantener
COL_CATEGORICAS = [
    'SEXO',
    'UBIGEO_PACIENTE',
    'DEPARTAMENTO_PACIENTE',
    'PROVINCIA_PACIENTE',
    'DISTRITO_PACIENTE',
    'DEPARTAMENTO_MUESTRA',
    'PROVINCIA_MUESTRA',
    'DISTRITO_MUESTRA',
    'TIPO_MUESTRA',
    'RESULTADO',
    'FECHA_CORTE'
]

# Columnas numéricas a mantener
COL_NUMERICO = [
    'EDAD'
]

# Eliminar columnas no deseadas
df.drop(columns=DROP_COLUMNS, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-c5c839e4b06b> in <cell line: 31>()
#      29
#      30 # Eliminar columnas no deseadas
# ---> 31 df.drop(columns=DROP_COLUMNS, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['INSTITIUTCION', 'UUID'] not found in axis"

# %%
# Eliminar filas donde la columna 'departamento_paciente' tiene valores nulos
df_cleaned = df.dropna(subset=['departamento_paciente'])

# %%
df.head()
# Out:
#    FECHA_CORTE  FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 0     20230927       20200724    26   FEMENINO         140137.0
# 1     20230927       20200901    27  MASCULINO         250104.0
# 2     20230927       20200901    33  MASCULINO         140133.0
# 3     20230927       20200901    46  MASCULINO         240106.0
# 4     20230927       20200826    39  MASCULINO         140140.0
#
#   DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE       DISTRITO_PACIENTE  \
# 0                  LIMA               LIMA  SAN JUAN DE LURIGANCHO
# 1               UCAYALI   CORONEL PORTILLO              CAMPOVERDE
# 2                  LIMA               LIMA             JESUS MARIA
# 3                                   CALLAO              VENTANILLA
# 4                  LIMA               LIMA               SAN BORJA
#
#   DEPARTAMENTO_MUESTRA PROVINCIA_MUESTRA   DISTRITO_MUESTRA  \
# 0                 LIMA              LIMA          SAN BORJA
# 1                 LIMA              LIMA        JESUS MARIA
# 2                 LIMA              LIMA        JESUS MARIA
# 3                 LIMA              LIMA        JESUS MARIA
# 4                 LIMA              LIMA  MAGDALENA DEL MAR
#
#                 TIPO_MUESTRA RESULTADO
# 0  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 2  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 3  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 4  HISOPADO NASAL Y FARINGEO  NEGATIVO

# %%
# prompt: delete the rows where UBIGEO_PACIENTE is null

import pandas as pd
df = df[pd.notnull(df['UBIGEO_PACIENTE'])]

# prompt: show me how many rows are so far

print(f"There are {df.shape[0]} rows in the DataFrame.")
# Out:
# There are 1048574 rows in the DataFrame.

# %%
# prompt: delete rows where PROVINCIA_PACIENTE is null

import pandas as pd
df = df[pd.notnull(df['PROVINCIA_PACIENTE'])]
print(f"There are {df.shape[0]} rows in the DataFrame.")
# Out:
# There are 1048566 rows in the DataFrame.

# %%
# prompt: select how many rows have PROVINCIA_PACIENTE is null

null_provincia_count = df['PROVINCIA_PACIENTE'].isnull().sum()
print(f"There are {null_provincia_count} rows where PROVINCIA_PACIENTE is null.")
# Out:
# There are 0 rows where PROVINCIA_PACIENTE is null.

# %%
import pandas as pd
df = df[pd.notnull(df['PROVINCIA_PACIENTE'])]

df = df[pd.notnull(df['DISTRITO_PACIENTE'])]

print(f"There are {df.shape[0]} rows in the DataFrame.")
# Out:
# There are 1048566 rows in the DataFrame.

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [FECHA_CORTE, FECHA_MUESTRA, EDAD, SEXO, UBIGEO_PACIENTE, DEPARTAMENTO_PACIENTE, PROVINCIA_PACIENTE, DISTRITO_PACIENTE, DEPARTAMENTO_MUESTRA, PROVINCIA_MUESTRA, DISTRITO_MUESTRA, TIPO_MUESTRA, RESULTADO]
# Index: []

# %%
# prompt: delete rows where EDAD is iqual or under 15

df = df[df['EDAD'] > 15]

# prompt: delete rows wehre EDAD is beyond 90

df = df[df['EDAD'] <= 90]

print(f"There are {df.shape[0]} rows in the DataFrame.")
df.head(50)
# Out:
# There are 1008718 rows in the DataFrame.
#     FECHA_CORTE  FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 0      20230927       20200724    26   FEMENINO         140137.0
# 1      20230927       20200901    27  MASCULINO         250104.0
# 2      20230927       20200901    33  MASCULINO         140133.0
# 3      20230927       20200901    46  MASCULINO         240106.0
# 4      20230927       20200826    39  MASCULINO         140140.0
# 5      20230927       20200826    58  MASCULINO          40127.0
# 6      20230927       20200826    53  MASCULINO          40103.0
# 7      20230927       20200824    32  MASCULINO          80312.0
# 8      20230927       20200824    32  MASCULINO          80302.0
# 9      20230927       20200724    51   FEMENINO         230103.0
# 10     20230927       20200724    57   FEMENINO         230304.0
# 11     20230927       20200723    32   FEMENINO         100103.0
# 12     20230927       20200729    46   FEMENINO         110901.0
# 13     20230927       20200731    69   FEMENINO         240101.0
# 14     20230927       20200729    28   FEMENINO         140101.0
# 15     20230927       20200901    32   FEMENINO         140108.0
# 16     20230927       20200901    27  MASCULINO          61201.0
# 17     20230927       20200901    48  MASCULINO          60101.0
# 18     20230927       20200824    40   FEMENINO         110113.0
# 19     20230927       20200824    36  MASCULINO          80301.0
# 20     20230927       20200824    36  MASCULINO         140136.0
# 21     20230927       20200718    20   FEMENINO          50107.0
# 22     20230927       20200716    22  MASCULINO          80519.0
# 23     20230927       20200715    33  MASCULINO          80101.0
# 24     20230927       20200830    41  MASCULINO         140131.0
# 25     20230927       20200830    56  MASCULINO          60101.0
# 26     20230927       20200828    44   FEMENINO         120506.0
# 27     20230927       20200724    44   FEMENINO         100101.0
# 28     20230927       20200724    44  MASCULINO         240105.0
# 29     20230927       20200724    26  MASCULINO         240102.0
# 30     20230927       20200731    59   FEMENINO          71303.0
# 31     20230927       20200731    21  MASCULINO         230101.0
# 32     20230927       20200730    57  MASCULINO         100101.0
# 33     20230927       20200901    43  MASCULINO          60101.0
# 34     20230927       20200901    23   FEMENINO         140130.0
# 35     20230927       20200901    50  MASCULINO          60202.0
# 36     20230927       20200715    22  MASCULINO          80201.0
# 37     20230927       20200717    47   FEMENINO          60801.0
# 38     20230927       20200717    40  MASCULINO         220101.0
# 39     20230927       20200717    44  MASCULINO         250107.0
# 40     20230927       20200717    33   FEMENINO         240101.0
# 41     20230927       20200731    59  MASCULINO         140101.0
# 42     20230927       20200730    46   FEMENINO          21301.0
# 43     20230927       20200731    45   FEMENINO          50107.0
# 44     20230927       20200718    31  MASCULINO         100304.0
# 45     20230927       20200714    58  MASCULINO         220112.0
# 46     20230927       20200714    37   FEMENINO         100110.0
# 47     20230927       20200713    37   FEMENINO         100101.0
# 48     20230927       20200718    34  MASCULINO          40101.0
# 49     20230927       20200718    55  MASCULINO          40101.0
#
#    DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE       DISTRITO_PACIENTE  \
# 0                   LIMA               LIMA  SAN JUAN DE LURIGANCHO
# 1                UCAYALI   CORONEL PORTILLO              CAMPOVERDE
# 2                   LIMA               LIMA             JESUS MARIA
# 3                                    CALLAO              VENTANILLA
# 4                   LIMA               LIMA               SAN BORJA
# 5               AREQUIPA           AREQUIPA           JACOBO HUNTER
# 6               AREQUIPA           AREQUIPA          CERRO COLORADO
# 7           HUANCAVELICA           ANGARAES             CCOCHACCASA
# 8           HUANCAVELICA           ANGARAES                ANCHONGA
# 9                 TUMBES             TUMBES                 LA CRUZ
# 10                TUMBES          ZARUMILLA            AGUAS VERDES
# 11                   ICA                ICA             LOS AQUIJES
# 12                 JUNIN            CHUPACA                 CHUPACA
# 13                                   CALLAO                  CALLAO
# 14                  LIMA               LIMA                    LIMA
# 15                  LIMA               LIMA              CHORRILLOS
# 16             CAJAMARCA         SAN MARCOS            PEDRO GALVEZ
# 17             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 18                 JUNIN           HUANCAYO                EL TAMBO
# 19          HUANCAVELICA           ANGARAES                  LIRCAY
# 20                  LIMA               LIMA  SAN JUAN DE MIRAFLORES
# 21              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 22          HUANCAVELICA           TAYACAJA              SALCABAMBA
# 23          HUANCAVELICA       HUANCAVELICA            HUANCAVELICA
# 24                  LIMA               LIMA               SURQUILLO
# 25             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 26           LA LIBERTAD          PACASMAYO               PACASMAYO
# 27                   ICA                ICA                     ICA
# 28                                   CALLAO                LA PERLA
# 29                                   CALLAO              BELLAVISTA
# 30                 CUSCO           URUBAMBA            HUAYLLABAMBA
# 31                TUMBES             TUMBES                  TUMBES
# 32                   ICA                ICA                     ICA
# 33             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 34                  LIMA               LIMA       SANTIAGO DE SURCO
# 35             CAJAMARCA          CAJABAMBA                CACHACHI
# 36          HUANCAVELICA           ACOBAMBA                ACOBAMBA
# 37             CAJAMARCA               JAEN                    JAEN
# 38                 TACNA              TACNA                   TACNA
# 39               UCAYALI   CORONEL PORTILLO                MANANTAY
# 40                                   CALLAO                  CALLAO
# 41                  LIMA               LIMA                    LIMA
# 42                ANCASH              SANTA                CHIMBOTE
# 43              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 44                   ICA              NAZCA                 MARCONA
# 45                 TACNA              TACNA            CIUDAD NUEVA
# 46                   ICA                ICA             SUBTANJALLA
# 47                   ICA                ICA                     ICA
# 48              AREQUIPA           AREQUIPA                AREQUIPA
# 49              AREQUIPA           AREQUIPA                AREQUIPA
#
#    DEPARTAMENTO_MUESTRA        PROVINCIA_MUESTRA  \
# 0                  LIMA                     LIMA
# 1                  LIMA                     LIMA
# 2                  LIMA                     LIMA
# 3                  LIMA                     LIMA
# 4                  LIMA                     LIMA
# 5                  LIMA                     LIMA
# 6                  LIMA                     LIMA
# 7                  LIMA                     LIMA
# 8                  LIMA                     LIMA
# 9                TUMBES                   TUMBES
# 10               TUMBES                   TUMBES
# 11                  ICA                      ICA
# 12                JUNIN                 HUANCAYO
# 13                 LIMA                     LIMA
# 14                 LIMA                   HUAURA
# 15                 LIMA                     LIMA
# 16                 LIMA                     LIMA
# 17                 LIMA                     LIMA
# 18                 LIMA                     LIMA
# 19                 LIMA                     LIMA
# 20                 LIMA                     LIMA
# 21             AYACUCHO                 HUAMANGA
# 22         HUANCAVELICA             HUANCAVELICA
# 23         HUANCAVELICA             HUANCAVELICA
# 24                 LIMA                     LIMA
# 25                 LIMA                     LIMA
# 26                 LIMA                     LIMA
# 27                  ICA                      ICA
# 28               CALLAO  PROV. CONST. DEL CALLAO
# 29               CALLAO  PROV. CONST. DEL CALLAO
# 30                CUSCO                    CUSCO
# 31               TUMBES                   TUMBES
# 32                  ICA                      ICA
# 33                 LIMA                     LIMA
# 34                 LIMA                     LIMA
# 35                 LIMA                     LIMA
# 36         HUANCAVELICA                 ACOBAMBA
# 37            CAJAMARCA                     JAEN
# 38                TACNA                    TACNA
# 39              UCAYALI         CORONEL PORTILLO
# 40                 PUNO                     PUNO
# 41               CALLAO  PROV. CONST. DEL CALLAO
# 42               ANCASH                   HUARAZ
# 43             AYACUCHO                 HUAMANGA
# 44                 LIMA                     LIMA
# 45                TACNA                    TACNA
# 46                  ICA                      ICA
# 47                  ICA                      ICA
# 48                 LIMA                     LIMA
# 49                 LIMA                     LIMA
#
#                         DISTRITO_MUESTRA               TIPO_MUESTRA RESULTADO
# 0                              SAN BORJA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 2                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 3                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 4                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 5                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 6                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 7                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 8                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 9                                 TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 10                                TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 11                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 12                              HUANCAYO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 13                SAN JUAN DE LURIGANCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 14                                HUACHO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 15                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 16                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 17                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 18                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 19                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 20                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 21                     SAN JUAN BAUTISTA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 22                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 23                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 24                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 25                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 26                            MIRAFLORES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 27                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 28                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 29                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 30                         SAN SEBASTIAN  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 31                                TUMBES  HISOPADO NASAL Y FARINGEO  POSITIVO
# 32                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 33                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 34                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 35                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 36                               PAUCARA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 37                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 38  CORONEL GREGORIO ALBARRACIN LANCHIPA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 39                           YARINACOCHA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 40                                  PUNO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 41                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 42                                HUARAZ  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 43                              AYACUCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 44                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 45                          CIUDAD NUEVA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 46                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 47                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 48                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 49                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO

# %%
print("Valores nulos antes de rellenar:")
print(df['DEPARTAMENTO_PACIENTE'].isnull().sum())

# Rellenar valores nulos
df['DEPARTAMENTO_PACIENTE'] = df['DEPARTAMENTO_PACIENTE'].fillna('CALLAO')

# Verificar valores nulos después de rellenar
print("Valores nulos después de rellenar:")
print(df['DEPARTAMENTO_PACIENTE'].isnull().sum())

# Mostrar algunas filas para verificar visualmente
print(df.head(50))
# Out:
# Valores nulos antes de rellenar:
# 0
# Valores nulos después de rellenar:
# 0
#     FECHA_CORTE  FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 0      20230927       20200724    26   FEMENINO         140137.0
# 1      20230927       20200901    27  MASCULINO         250104.0
# 2      20230927       20200901    33  MASCULINO         140133.0
# 3      20230927       20200901    46  MASCULINO         240106.0
# 4      20230927       20200826    39  MASCULINO         140140.0
# 5      20230927       20200826    58  MASCULINO          40127.0
# 6      20230927       20200826    53  MASCULINO          40103.0
# 7      20230927       20200824    32  MASCULINO          80312.0
# 8      20230927       20200824    32  MASCULINO          80302.0
# 9      20230927       20200724    51   FEMENINO         230103.0
# 10     20230927       20200724    57   FEMENINO         230304.0
# 11     20230927       20200723    32   FEMENINO         100103.0
# 12     20230927       20200729    46   FEMENINO         110901.0
# 13     20230927       20200731    69   FEMENINO         240101.0
# 14     20230927       20200729    28   FEMENINO         140101.0
# 15     20230927       20200901    32   FEMENINO         140108.0
# 16     20230927       20200901    27  MASCULINO          61201.0
# 17     20230927       20200901    48  MASCULINO          60101.0
# 18     20230927       20200824    40   FEMENINO         110113.0
# 19     20230927       20200824    36  MASCULINO          80301.0
# 20     20230927       20200824    36  MASCULINO         140136.0
# 21     20230927       20200718    20   FEMENINO          50107.0
# 22     20230927       20200716    22  MASCULINO          80519.0
# 23     20230927       20200715    33  MASCULINO          80101.0
# 24     20230927       20200830    41  MASCULINO         140131.0
# 25     20230927       20200830    56  MASCULINO          60101.0
# 26     20230927       20200828    44   FEMENINO         120506.0
# 27     20230927       20200724    44   FEMENINO         100101.0
# 28     20230927       20200724    44  MASCULINO         240105.0
# 29     20230927       20200724    26  MASCULINO         240102.0
# 30     20230927       20200731    59   FEMENINO          71303.0
# 31     20230927       20200731    21  MASCULINO         230101.0
# 32     20230927       20200730    57  MASCULINO         100101.0
# 33     20230927       20200901    43  MASCULINO          60101.0
# 34     20230927       20200901    23   FEMENINO         140130.0
# 35     20230927       20200901    50  MASCULINO          60202.0
# 36     20230927       20200715    22  MASCULINO          80201.0
# 37     20230927       20200717    47   FEMENINO          60801.0
# 38     20230927       20200717    40  MASCULINO         220101.0
# 39     20230927       20200717    44  MASCULINO         250107.0
# 40     20230927       20200717    33   FEMENINO         240101.0
# 41     20230927       20200731    59  MASCULINO         140101.0
# 42     20230927       20200730    46   FEMENINO          21301.0
# 43     20230927       20200731    45   FEMENINO          50107.0
# 44     20230927       20200718    31  MASCULINO         100304.0
# 45     20230927       20200714    58  MASCULINO         220112.0
# 46     20230927       20200714    37   FEMENINO         100110.0
# 47     20230927       20200713    37   FEMENINO         100101.0
# 48     20230927       20200718    34  MASCULINO          40101.0
# 49     20230927       20200718    55  MASCULINO          40101.0
#
#    DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE       DISTRITO_PACIENTE  \
# 0                   LIMA               LIMA  SAN JUAN DE LURIGANCHO
# 1                UCAYALI   CORONEL PORTILLO              CAMPOVERDE
# 2                   LIMA               LIMA             JESUS MARIA
# 3                                    CALLAO              VENTANILLA
# 4                   LIMA               LIMA               SAN BORJA
# 5               AREQUIPA           AREQUIPA           JACOBO HUNTER
# 6               AREQUIPA           AREQUIPA          CERRO COLORADO
# 7           HUANCAVELICA           ANGARAES             CCOCHACCASA
# 8           HUANCAVELICA           ANGARAES                ANCHONGA
# 9                 TUMBES             TUMBES                 LA CRUZ
# 10                TUMBES          ZARUMILLA            AGUAS VERDES
# 11                   ICA                ICA             LOS AQUIJES
# 12                 JUNIN            CHUPACA                 CHUPACA
# 13                                   CALLAO                  CALLAO
# 14                  LIMA               LIMA                    LIMA
# 15                  LIMA               LIMA              CHORRILLOS
# 16             CAJAMARCA         SAN MARCOS            PEDRO GALVEZ
# 17             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 18                 JUNIN           HUANCAYO                EL TAMBO
# 19          HUANCAVELICA           ANGARAES                  LIRCAY
# 20                  LIMA               LIMA  SAN JUAN DE MIRAFLORES
# 21              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 22          HUANCAVELICA           TAYACAJA              SALCABAMBA
# 23          HUANCAVELICA       HUANCAVELICA            HUANCAVELICA
# 24                  LIMA               LIMA               SURQUILLO
# 25             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 26           LA LIBERTAD          PACASMAYO               PACASMAYO
# 27                   ICA                ICA                     ICA
# 28                                   CALLAO                LA PERLA
# 29                                   CALLAO              BELLAVISTA
# 30                 CUSCO           URUBAMBA            HUAYLLABAMBA
# 31                TUMBES             TUMBES                  TUMBES
# 32                   ICA                ICA                     ICA
# 33             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 34                  LIMA               LIMA       SANTIAGO DE SURCO
# 35             CAJAMARCA          CAJABAMBA                CACHACHI
# 36          HUANCAVELICA           ACOBAMBA                ACOBAMBA
# 37             CAJAMARCA               JAEN                    JAEN
# 38                 TACNA              TACNA                   TACNA
# 39               UCAYALI   CORONEL PORTILLO                MANANTAY
# 40                                   CALLAO                  CALLAO
# 41                  LIMA               LIMA                    LIMA
# 42                ANCASH              SANTA                CHIMBOTE
# 43              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 44                   ICA              NAZCA                 MARCONA
# 45                 TACNA              TACNA            CIUDAD NUEVA
# 46                   ICA                ICA             SUBTANJALLA
# 47                   ICA                ICA                     ICA
# 48              AREQUIPA           AREQUIPA                AREQUIPA
# 49              AREQUIPA           AREQUIPA                AREQUIPA
#
#    DEPARTAMENTO_MUESTRA        PROVINCIA_MUESTRA  \
# 0                  LIMA                     LIMA
# 1                  LIMA                     LIMA
# 2                  LIMA                     LIMA
# 3                  LIMA                     LIMA
# 4                  LIMA                     LIMA
# 5                  LIMA                     LIMA
# 6                  LIMA                     LIMA
# 7                  LIMA                     LIMA
# 8                  LIMA                     LIMA
# 9                TUMBES                   TUMBES
# 10               TUMBES                   TUMBES
# 11                  ICA                      ICA
# 12                JUNIN                 HUANCAYO
# 13                 LIMA                     LIMA
# 14                 LIMA                   HUAURA
# 15                 LIMA                     LIMA
# 16                 LIMA                     LIMA
# 17                 LIMA                     LIMA
# 18                 LIMA                     LIMA
# 19                 LIMA                     LIMA
# 20                 LIMA                     LIMA
# 21             AYACUCHO                 HUAMANGA
# 22         HUANCAVELICA             HUANCAVELICA
# 23         HUANCAVELICA             HUANCAVELICA
# 24                 LIMA                     LIMA
# 25                 LIMA                     LIMA
# 26                 LIMA                     LIMA
# 27                  ICA                      ICA
# 28               CALLAO  PROV. CONST. DEL CALLAO
# 29               CALLAO  PROV. CONST. DEL CALLAO
# 30                CUSCO                    CUSCO
# 31               TUMBES                   TUMBES
# 32                  ICA                      ICA
# 33                 LIMA                     LIMA
# 34                 LIMA                     LIMA
# 35                 LIMA                     LIMA
# 36         HUANCAVELICA                 ACOBAMBA
# 37            CAJAMARCA                     JAEN
# 38                TACNA                    TACNA
# 39              UCAYALI         CORONEL PORTILLO
# 40                 PUNO                     PUNO
# 41               CALLAO  PROV. CONST. DEL CALLAO
# 42               ANCASH                   HUARAZ
# 43             AYACUCHO                 HUAMANGA
# 44                 LIMA                     LIMA
# 45                TACNA                    TACNA
# 46                  ICA                      ICA
# 47                  ICA                      ICA
# 48                 LIMA                     LIMA
# 49                 LIMA                     LIMA
#
#                         DISTRITO_MUESTRA               TIPO_MUESTRA RESULTADO
# 0                              SAN BORJA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 2                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 3                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 4                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 5                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 6                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 7                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 8                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 9                                 TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 10                                TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 11                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 12                              HUANCAYO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 13                SAN JUAN DE LURIGANCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 14                                HUACHO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 15                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 16                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 17                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 18                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 19                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 20                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 21                     SAN JUAN BAUTISTA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 22                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 23                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 24                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 25                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 26                            MIRAFLORES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 27                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 28                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 29                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 30                         SAN SEBASTIAN  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 31                                TUMBES  HISOPADO NASAL Y FARINGEO  POSITIVO
# 32                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 33                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 34                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 35                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 36                               PAUCARA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 37                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 38  CORONEL GREGORIO ALBARRACIN LANCHIPA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 39                           YARINACOCHA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 40                                  PUNO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 41                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 42                                HUARAZ  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 43                              AYACUCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 44                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 45                          CIUDAD NUEVA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 46                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 47                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 48                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 49                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO

# %%
# Verificar valores nulos antes de rellenar
print("Valores nulos antes de rellenar:")
print(df['DEPARTAMENTO_PACIENTE'].isnull().sum())

# Rellenar valores nulos
df['DEPARTAMENTO_PACIENTE'] = df['DEPARTAMENTO_PACIENTE'].fillna('CALLAO')

# Verificar valores nulos después de rellenar
print("Valores nulos después de rellenar:")
print(df['DEPARTAMENTO_PACIENTE'].isnull().sum())

# Verificar cuántas filas tienen cadenas vacías o espacios en blanco
empty_strings_count = df['DEPARTAMENTO_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco: {empty_strings_count}")

# Reemplazar cadenas vacías o espacios en blanco con 'CALLAO'
df['DEPARTAMENTO_PACIENTE'] = df['DEPARTAMENTO_PACIENTE'].apply(lambda x: 'CALLAO' if isinstance(x, str) and x.strip() == '' else x)

# Verificar nuevamente cuántas filas tienen cadenas vacías o espacios en blanco
empty_strings_count_after = df['DEPARTAMENTO_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco después del reemplazo: {empty_strings_count_after}")

# Mostrar algunas filas para verificar visualmente
df.head(50)
# Out:
# Valores nulos antes de rellenar:
# 0
# Valores nulos después de rellenar:
# 0
# Filas con cadenas vacías o espacios en blanco: 24146
# Filas con cadenas vacías o espacios en blanco después del reemplazo: 0
#     FECHA_CORTE  FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 0      20230927       20200724    26   FEMENINO         140137.0
# 1      20230927       20200901    27  MASCULINO         250104.0
# 2      20230927       20200901    33  MASCULINO         140133.0
# 3      20230927       20200901    46  MASCULINO         240106.0
# 4      20230927       20200826    39  MASCULINO         140140.0
# 5      20230927       20200826    58  MASCULINO          40127.0
# 6      20230927       20200826    53  MASCULINO          40103.0
# 7      20230927       20200824    32  MASCULINO          80312.0
# 8      20230927       20200824    32  MASCULINO          80302.0
# 9      20230927       20200724    51   FEMENINO         230103.0
# 10     20230927       20200724    57   FEMENINO         230304.0
# 11     20230927       20200723    32   FEMENINO         100103.0
# 12     20230927       20200729    46   FEMENINO         110901.0
# 13     20230927       20200731    69   FEMENINO         240101.0
# 14     20230927       20200729    28   FEMENINO         140101.0
# 15     20230927       20200901    32   FEMENINO         140108.0
# 16     20230927       20200901    27  MASCULINO          61201.0
# 17     20230927       20200901    48  MASCULINO          60101.0
# 18     20230927       20200824    40   FEMENINO         110113.0
# 19     20230927       20200824    36  MASCULINO          80301.0
# 20     20230927       20200824    36  MASCULINO         140136.0
# 21     20230927       20200718    20   FEMENINO          50107.0
# 22     20230927       20200716    22  MASCULINO          80519.0
# 23     20230927       20200715    33  MASCULINO          80101.0
# 24     20230927       20200830    41  MASCULINO         140131.0
# 25     20230927       20200830    56  MASCULINO          60101.0
# 26     20230927       20200828    44   FEMENINO         120506.0
# 27     20230927       20200724    44   FEMENINO         100101.0
# 28     20230927       20200724    44  MASCULINO         240105.0
# 29     20230927       20200724    26  MASCULINO         240102.0
# 30     20230927       20200731    59   FEMENINO          71303.0
# 31     20230927       20200731    21  MASCULINO         230101.0
# 32     20230927       20200730    57  MASCULINO         100101.0
# 33     20230927       20200901    43  MASCULINO          60101.0
# 34     20230927       20200901    23   FEMENINO         140130.0
# 35     20230927       20200901    50  MASCULINO          60202.0
# 36     20230927       20200715    22  MASCULINO          80201.0
# 37     20230927       20200717    47   FEMENINO          60801.0
# 38     20230927       20200717    40  MASCULINO         220101.0
# 39     20230927       20200717    44  MASCULINO         250107.0
# 40     20230927       20200717    33   FEMENINO         240101.0
# 41     20230927       20200731    59  MASCULINO         140101.0
# 42     20230927       20200730    46   FEMENINO          21301.0
# 43     20230927       20200731    45   FEMENINO          50107.0
# 44     20230927       20200718    31  MASCULINO         100304.0
# 45     20230927       20200714    58  MASCULINO         220112.0
# 46     20230927       20200714    37   FEMENINO         100110.0
# 47     20230927       20200713    37   FEMENINO         100101.0
# 48     20230927       20200718    34  MASCULINO          40101.0
# 49     20230927       20200718    55  MASCULINO          40101.0
#
#    DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE       DISTRITO_PACIENTE  \
# 0                   LIMA               LIMA  SAN JUAN DE LURIGANCHO
# 1                UCAYALI   CORONEL PORTILLO              CAMPOVERDE
# 2                   LIMA               LIMA             JESUS MARIA
# 3                 CALLAO             CALLAO              VENTANILLA
# 4                   LIMA               LIMA               SAN BORJA
# 5               AREQUIPA           AREQUIPA           JACOBO HUNTER
# 6               AREQUIPA           AREQUIPA          CERRO COLORADO
# 7           HUANCAVELICA           ANGARAES             CCOCHACCASA
# 8           HUANCAVELICA           ANGARAES                ANCHONGA
# 9                 TUMBES             TUMBES                 LA CRUZ
# 10                TUMBES          ZARUMILLA            AGUAS VERDES
# 11                   ICA                ICA             LOS AQUIJES
# 12                 JUNIN            CHUPACA                 CHUPACA
# 13                CALLAO             CALLAO                  CALLAO
# 14                  LIMA               LIMA                    LIMA
# 15                  LIMA               LIMA              CHORRILLOS
# 16             CAJAMARCA         SAN MARCOS            PEDRO GALVEZ
# 17             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 18                 JUNIN           HUANCAYO                EL TAMBO
# 19          HUANCAVELICA           ANGARAES                  LIRCAY
# 20                  LIMA               LIMA  SAN JUAN DE MIRAFLORES
# 21              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 22          HUANCAVELICA           TAYACAJA              SALCABAMBA
# 23          HUANCAVELICA       HUANCAVELICA            HUANCAVELICA
# 24                  LIMA               LIMA               SURQUILLO
# 25             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 26           LA LIBERTAD          PACASMAYO               PACASMAYO
# 27                   ICA                ICA                     ICA
# 28                CALLAO             CALLAO                LA PERLA
# 29                CALLAO             CALLAO              BELLAVISTA
# 30                 CUSCO           URUBAMBA            HUAYLLABAMBA
# 31                TUMBES             TUMBES                  TUMBES
# 32                   ICA                ICA                     ICA
# 33             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 34                  LIMA               LIMA       SANTIAGO DE SURCO
# 35             CAJAMARCA          CAJABAMBA                CACHACHI
# 36          HUANCAVELICA           ACOBAMBA                ACOBAMBA
# 37             CAJAMARCA               JAEN                    JAEN
# 38                 TACNA              TACNA                   TACNA
# 39               UCAYALI   CORONEL PORTILLO                MANANTAY
# 40                CALLAO             CALLAO                  CALLAO
# 41                  LIMA               LIMA                    LIMA
# 42                ANCASH              SANTA                CHIMBOTE
# 43              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 44                   ICA              NAZCA                 MARCONA
# 45                 TACNA              TACNA            CIUDAD NUEVA
# 46                   ICA                ICA             SUBTANJALLA
# 47                   ICA                ICA                     ICA
# 48              AREQUIPA           AREQUIPA                AREQUIPA
# 49              AREQUIPA           AREQUIPA                AREQUIPA
#
#    DEPARTAMENTO_MUESTRA        PROVINCIA_MUESTRA  \
# 0                  LIMA                     LIMA
# 1                  LIMA                     LIMA
# 2                  LIMA                     LIMA
# 3                  LIMA                     LIMA
# 4                  LIMA                     LIMA
# 5                  LIMA                     LIMA
# 6                  LIMA                     LIMA
# 7                  LIMA                     LIMA
# 8                  LIMA                     LIMA
# 9                TUMBES                   TUMBES
# 10               TUMBES                   TUMBES
# 11                  ICA                      ICA
# 12                JUNIN                 HUANCAYO
# 13                 LIMA                     LIMA
# 14                 LIMA                   HUAURA
# 15                 LIMA                     LIMA
# 16                 LIMA                     LIMA
# 17                 LIMA                     LIMA
# 18                 LIMA                     LIMA
# 19                 LIMA                     LIMA
# 20                 LIMA                     LIMA
# 21             AYACUCHO                 HUAMANGA
# 22         HUANCAVELICA             HUANCAVELICA
# 23         HUANCAVELICA             HUANCAVELICA
# 24                 LIMA                     LIMA
# 25                 LIMA                     LIMA
# 26                 LIMA                     LIMA
# 27                  ICA                      ICA
# 28               CALLAO  PROV. CONST. DEL CALLAO
# 29               CALLAO  PROV. CONST. DEL CALLAO
# 30                CUSCO                    CUSCO
# 31               TUMBES                   TUMBES
# 32                  ICA                      ICA
# 33                 LIMA                     LIMA
# 34                 LIMA                     LIMA
# 35                 LIMA                     LIMA
# 36         HUANCAVELICA                 ACOBAMBA
# 37            CAJAMARCA                     JAEN
# 38                TACNA                    TACNA
# 39              UCAYALI         CORONEL PORTILLO
# 40                 PUNO                     PUNO
# 41               CALLAO  PROV. CONST. DEL CALLAO
# 42               ANCASH                   HUARAZ
# 43             AYACUCHO                 HUAMANGA
# 44                 LIMA                     LIMA
# 45                TACNA                    TACNA
# 46                  ICA                      ICA
# 47                  ICA                      ICA
# 48                 LIMA                     LIMA
# 49                 LIMA                     LIMA
#
#                         DISTRITO_MUESTRA               TIPO_MUESTRA RESULTADO
# 0                              SAN BORJA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 2                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 3                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 4                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 5                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 6                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 7                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 8                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 9                                 TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 10                                TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 11                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 12                              HUANCAYO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 13                SAN JUAN DE LURIGANCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 14                                HUACHO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 15                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 16                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 17                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 18                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 19                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 20                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 21                     SAN JUAN BAUTISTA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 22                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 23                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 24                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 25                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 26                            MIRAFLORES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 27                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 28                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 29                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 30                         SAN SEBASTIAN  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 31                                TUMBES  HISOPADO NASAL Y FARINGEO  POSITIVO
# 32                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 33                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 34                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 35                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 36                               PAUCARA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 37                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 38  CORONEL GREGORIO ALBARRACIN LANCHIPA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 39                           YARINACOCHA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 40                                  PUNO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 41                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 42                                HUARAZ  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 43                              AYACUCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 44                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 45                          CIUDAD NUEVA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 46                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 47                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 48                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 49                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO

# %%
# Mostrar cantidad de filas antes de eliminar
print(f"Total de filas antes de eliminar: {df.shape[0]}")

# Eliminar filas donde DEPARTAMENTO_PACIENTE es igual a 'NO DEFINIDO'
df = df[df['DEPARTAMENTO_PACIENTE'] != '[NO DEFINIDO]']

# Mostrar cantidad de filas después de eliminar
print(f"Total de filas después de eliminar: {df.shape[0]}")

# Verificar que se eliminaron correctamente
print(df[df['DEPARTAMENTO_PACIENTE'] == '[NO DEFINIDO]'])

df_ubigeo_paciente_null = df[df['DEPARTAMENTO_PACIENTE'] == 'CALLAO']

# Mostrar algunas filas para verificar
print(df_ubigeo_paciente_null.head(50))

# Mostrar la cantidad de filas seleccionadas
print(f"Total de filas con DEPARTAMENTO_PACIENTE igual a 'CALLAO': {df_ubigeo_paciente_null.shape[0]}")
# Out:
# Total de filas antes de eliminar: 1008718
# Total de filas después de eliminar: 1008709
# Empty DataFrame
# Columns: [FECHA_CORTE, FECHA_MUESTRA, EDAD, SEXO, UBIGEO_PACIENTE, DEPARTAMENTO_PACIENTE, PROVINCIA_PACIENTE, DISTRITO_PACIENTE, DEPARTAMENTO_MUESTRA, PROVINCIA_MUESTRA, DISTRITO_MUESTRA, TIPO_MUESTRA, RESULTADO]
# Index: []
#       FECHA_CORTE  FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 3        20230927       20200901    46  MASCULINO         240106.0
# 13       20230927       20200731    69   FEMENINO         240101.0
# 28       20230927       20200724    44  MASCULINO         240105.0
# 29       20230927       20200724    26  MASCULINO         240102.0
# 40       20230927       20200717    33   FEMENINO         240101.0
# 176      20230927       20200824    61  MASCULINO         240101.0
# 207      20230927       20210723    30  MASCULINO         240106.0
# 213      20230927       20211013    49   FEMENINO         240106.0
# 220      20230927       20211013    24   FEMENINO         240101.0
# 226      20230927       20211012    42  MASCULINO         240105.0
# 342      20230927       20200914    59   FEMENINO         240101.0
# 364      20230927       20200909    36   FEMENINO         240101.0
# 368      20230927       20200914    90  MASCULINO         240101.0
# 455      20230927       20200807    48  MASCULINO         240101.0
# 489      20230927       20200706    76   FEMENINO         240102.0
# 499      20230927       20200706    57   FEMENINO         240101.0
# 505      20230927       20200708    36  MASCULINO         240107.0
# 510      20230927       20200706    29  MASCULINO         240101.0
# 586      20230927       20200804    46  MASCULINO         240104.0
# 678      20230927       20201016    49  MASCULINO         240101.0
# 749      20230927       20211013    61  MASCULINO         240101.0
# 769      20230927       20211013    39   FEMENINO         240102.0
# 774      20230927       20200914    34   FEMENINO         240101.0
# 780      20230927       20200917    17   FEMENINO         240101.0
# 797      20230927       20211013    43  MASCULINO         240106.0
# 814      20230927       20211013    31   FEMENINO         240106.0
# 816      20230927       20211013    35  MASCULINO         240105.0
# 819      20230927       20200918    28  MASCULINO         240101.0
# 864      20230927       20211013    40   FEMENINO         240101.0
# 869      20230927       20201001    38  MASCULINO         240106.0
# 985      20230927       20200806    31  MASCULINO         240106.0
# 1073     20230927       20200706    44   FEMENINO         240107.0
# 1143     20230927       20211012    58   FEMENINO         240101.0
# 1144     20230927       20211012    64   FEMENINO         240101.0
# 1150     20230927       20211013    28  MASCULINO         240106.0
# 1205     20230927       20211012    48  MASCULINO         240101.0
# 1231     20230927       20200721    48  MASCULINO         240101.0
# 1232     20230927       20200720    53  MASCULINO         240102.0
# 1256     20230927       20201201    25   FEMENINO         240106.0
# 1270     20230927       20201215    19  MASCULINO         240105.0
# 1280     20230927       20201013    27   FEMENINO         240101.0
# 1382     20230927       20211013    44  MASCULINO         240102.0
# 1453     20230927       20201207    30   FEMENINO         240106.0
# 1462     20230927       20210707    22   FEMENINO         240101.0
# 1496     20230927       20200727    65   FEMENINO         240101.0
# 1533     20230927       20200908    47  MASCULINO         240102.0
# 1538     20230927       20200730    65  MASCULINO         240101.0
# 1539     20230927       20200730    50   FEMENINO         240101.0
# 1566     20230927       20211012    25  MASCULINO         240101.0
# 1574     20230927       20211011    20  MASCULINO         240107.0
#
#      DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE           DISTRITO_PACIENTE  \
# 3                   CALLAO             CALLAO                  VENTANILLA
# 13                  CALLAO             CALLAO                      CALLAO
# 28                  CALLAO             CALLAO                    LA PERLA
# 29                  CALLAO             CALLAO                  BELLAVISTA
# 40                  CALLAO             CALLAO                      CALLAO
# 176                 CALLAO             CALLAO                      CALLAO
# 207                 CALLAO             CALLAO                  VENTANILLA
# 213                 CALLAO             CALLAO                  VENTANILLA
# 220                 CALLAO             CALLAO                      CALLAO
# 226                 CALLAO             CALLAO                    LA PERLA
# 342                 CALLAO             CALLAO                      CALLAO
# 364                 CALLAO             CALLAO                      CALLAO
# 368                 CALLAO             CALLAO                      CALLAO
# 455                 CALLAO             CALLAO                      CALLAO
# 489                 CALLAO             CALLAO                  BELLAVISTA
# 499                 CALLAO             CALLAO                      CALLAO
# 505                 CALLAO             CALLAO                     MI PERU
# 510                 CALLAO             CALLAO                      CALLAO
# 586                 CALLAO             CALLAO  CARMEN DE LA LEGUA-REYNOSO
# 678                 CALLAO             CALLAO                      CALLAO
# 749                 CALLAO             CALLAO                      CALLAO
# 769                 CALLAO             CALLAO                  BELLAVISTA
# 774                 CALLAO             CALLAO                      CALLAO
# 780                 CALLAO             CALLAO                      CALLAO
# 797                 CALLAO             CALLAO                  VENTANILLA
# 814                 CALLAO             CALLAO                  VENTANILLA
# 816                 CALLAO             CALLAO                    LA PERLA
# 819                 CALLAO             CALLAO                      CALLAO
# 864                 CALLAO             CALLAO                      CALLAO
# 869                 CALLAO             CALLAO                  VENTANILLA
# 985                 CALLAO             CALLAO                  VENTANILLA
# 1073                CALLAO             CALLAO                     MI PERU
# 1143                CALLAO             CALLAO                      CALLAO
# 1144                CALLAO             CALLAO                      CALLAO
# 1150                CALLAO             CALLAO                  VENTANILLA
# 1205                CALLAO             CALLAO                      CALLAO
# 1231                CALLAO             CALLAO                      CALLAO
# 1232                CALLAO             CALLAO                  BELLAVISTA
# 1256                CALLAO             CALLAO                  VENTANILLA
# 1270                CALLAO             CALLAO                    LA PERLA
# 1280                CALLAO             CALLAO                      CALLAO
# 1382                CALLAO             CALLAO                  BELLAVISTA
# 1453                CALLAO             CALLAO                  VENTANILLA
# 1462                CALLAO             CALLAO                      CALLAO
# 1496                CALLAO             CALLAO                      CALLAO
# 1533                CALLAO             CALLAO                  BELLAVISTA
# 1538                CALLAO             CALLAO                      CALLAO
# 1539                CALLAO             CALLAO                      CALLAO
# 1566                CALLAO             CALLAO                      CALLAO
# 1574                CALLAO             CALLAO                     MI PERU
#
#      DEPARTAMENTO_MUESTRA        PROVINCIA_MUESTRA  \
# 3                    LIMA                     LIMA
# 13                   LIMA                     LIMA
# 28                 CALLAO  PROV. CONST. DEL CALLAO
# 29                 CALLAO  PROV. CONST. DEL CALLAO
# 40                   PUNO                     PUNO
# 176                  LIMA                     LIMA
# 207                  LIMA                     LIMA
# 213                  LIMA                     LIMA
# 220                  LIMA                     LIMA
# 226                  LIMA                     LIMA
# 342                CALLAO  PROV. CONST. DEL CALLAO
# 364                  LIMA                     LIMA
# 368                CALLAO  PROV. CONST. DEL CALLAO
# 455                  LIMA                     LIMA
# 489                CALLAO  PROV. CONST. DEL CALLAO
# 499                CALLAO  PROV. CONST. DEL CALLAO
# 505                  LIMA                     LIMA
# 510                  LIMA                     LIMA
# 586                CALLAO  PROV. CONST. DEL CALLAO
# 678                  LIMA                     LIMA
# 749                  LIMA                     LIMA
# 769                  LIMA                     LIMA
# 774                  LIMA                     LIMA
# 780                  LIMA                     LIMA
# 797                  LIMA                     LIMA
# 814                  LIMA                     LIMA
# 816              MOQUEGUA           MARISCAL NIETO
# 819                  LIMA                     LIMA
# 864                  LIMA                     LIMA
# 869                  LIMA                     LIMA
# 985                  LIMA                     LIMA
# 1073                 LIMA                     LIMA
# 1143                 LIMA                     LIMA
# 1144                 LIMA                     LIMA
# 1150                 LIMA                     LIMA
# 1205             MOQUEGUA           MARISCAL NIETO
# 1231                 LIMA                     LIMA
# 1232                 LIMA                     LIMA
# 1256                 LIMA                     LIMA
# 1270                 LIMA                     LIMA
# 1280               CALLAO  PROV. CONST. DEL CALLAO
# 1382                 LIMA                     LIMA
# 1453             MOQUEGUA           MARISCAL NIETO
# 1462                 LIMA                     LIMA
# 1496                 LIMA                     LIMA
# 1533                 LIMA                     LIMA
# 1538               CALLAO  PROV. CONST. DEL CALLAO
# 1539               CALLAO  PROV. CONST. DEL CALLAO
# 1566             MOQUEGUA           MARISCAL NIETO
# 1574                 LIMA                     LIMA
#
#                     DISTRITO_MUESTRA               TIPO_MUESTRA RESULTADO
# 3                        JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 13            SAN JUAN DE LURIGANCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 28                        BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 29                        BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 40                              PUNO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 176                      JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 207                       SAN ISIDRO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 213                             LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 220                            RIMAC  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 226                             LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 342                           CALLAO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 364                             LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 368                           CALLAO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 455                      JESUS MARIA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 489                           CALLAO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 499                           CALLAO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 505                      JESUS MARIA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 510                      JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 586       CARMEN DE LA LEGUA REYNOSO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 678                MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 749                       SAN ISIDRO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 769                       LOS OLIVOS  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 774                       SAN ISIDRO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 780                             LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 797                             LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 814                             LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 816                         MOQUEGUA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 819                      JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 864                       SAN ISIDRO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 869                SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 985                      JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1073                           COMAS  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1143            SAN MARTIN DE PORRES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1144            SAN MARTIN DE PORRES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1150                      SAN ISIDRO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1205                        MOQUEGUA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1231                       SAN BORJA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 1232                       SAN BORJA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 1256                   INDEPENDENCIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1270  PUEBLO LIBRE (MAGDALENA VIEJA)  HISOPADO NASAL Y FARINGEO  POSITIVO
# 1280                      BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1382                           BREÑA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1453                        MOQUEGUA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1462               MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1496                       SAN BORJA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1533                      MIRAFLORES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1538                          CALLAO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1539                          CALLAO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1566                        MOQUEGUA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1574                            LIMA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# Total de filas con DEPARTAMENTO_PACIENTE igual a 'CALLAO': 35313

# %%
# Verificar cuántas filas tienen cadenas vacías o espacios en blanco
empty_strings_count = df['PROVINCIA_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco: {empty_strings_count}")
empty_strings_count = df['DEPARTAMENTO_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco: {empty_strings_count}")
empty_strings_count = df['DISTRITO_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco: {empty_strings_count}")
# Verificar valores nulos antes de rellenar
print("Valores nulos antes de rellenar:")
print(df['DEPARTAMENTO_PACIENTE'].isnull().sum())
print("Valores nulos antes de rellenar:")
print(df['PROVINCIA_PACIENTE'].isnull().sum())
print("Valores nulos antes de rellenar:")
print(df['DISTRITO_PACIENTE'].isnull().sum())
# Out:
# Filas con cadenas vacías o espacios en blanco: 2
# Filas con cadenas vacías o espacios en blanco: 0
# Filas con cadenas vacías o espacios en blanco: 2
# Valores nulos antes de rellenar:
# 0
# Valores nulos antes de rellenar:
# 0
# Valores nulos antes de rellenar:
# 0

# %%
# Eliminar las filas donde 'PROVINCIA_PACIENTE' y 'DISTRITO_PACIENTE' son cadenas vacías
df_filtrado = df[(df['PROVINCIA_PACIENTE'].str.strip() != '') & (df['DISTRITO_PACIENTE'].str.strip() != '')]

# Verificar valores nulos después de filtrar
print("Valores nulos después de filtrar:")
print(df_filtrado['DEPARTAMENTO_PACIENTE'].isnull().sum())
print(df_filtrado['PROVINCIA_PACIENTE'].isnull().sum())
print(df_filtrado['DISTRITO_PACIENTE'].isnull().sum())

# Verificar recuentos de cadenas vacías después del filtrado
empty_strings_count = df_filtrado['PROVINCIA_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco en 'PROVINCIA_PACIENTE': {empty_strings_count}")
empty_strings_count = df_filtrado['DISTRITO_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco en 'DISTRITO_PACIENTE': {empty_strings_count}")

empty_strings_count = df_filtrado['DISTRITO_PACIENTE'].apply(lambda x: x.strip() == '' if isinstance(x, str) else False).sum()
print(f"Filas con cadenas vacías o espacios en blanco en 'PROVINCIA_PACIENTE': {empty_strings_count}")

# Obtener el total de filas en el DataFrame filtrado
total_filas = len(df_filtrado)

# Mostrar el total de filas
print(f"Total de filas después del filtrado: {total_filas}")
# Out:
# Valores nulos después de filtrar:
# 0
# 0
# 0
# Filas con cadenas vacías o espacios en blanco en 'PROVINCIA_PACIENTE': 0
# Filas con cadenas vacías o espacios en blanco en 'DISTRITO_PACIENTE': 0
# Filas con cadenas vacías o espacios en blanco en 'PROVINCIA_PACIENTE': 0
# Total de filas después del filtrado: 1008707

# %%
df.head(50)
# Out:
#     FECHA_CORTE  FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 0      20230927       20200724    26   FEMENINO         140137.0
# 1      20230927       20200901    27  MASCULINO         250104.0
# 2      20230927       20200901    33  MASCULINO         140133.0
# 3      20230927       20200901    46  MASCULINO         240106.0
# 4      20230927       20200826    39  MASCULINO         140140.0
# 5      20230927       20200826    58  MASCULINO          40127.0
# 6      20230927       20200826    53  MASCULINO          40103.0
# 7      20230927       20200824    32  MASCULINO          80312.0
# 8      20230927       20200824    32  MASCULINO          80302.0
# 9      20230927       20200724    51   FEMENINO         230103.0
# 10     20230927       20200724    57   FEMENINO         230304.0
# 11     20230927       20200723    32   FEMENINO         100103.0
# 12     20230927       20200729    46   FEMENINO         110901.0
# 13     20230927       20200731    69   FEMENINO         240101.0
# 14     20230927       20200729    28   FEMENINO         140101.0
# 15     20230927       20200901    32   FEMENINO         140108.0
# 16     20230927       20200901    27  MASCULINO          61201.0
# 17     20230927       20200901    48  MASCULINO          60101.0
# 18     20230927       20200824    40   FEMENINO         110113.0
# 19     20230927       20200824    36  MASCULINO          80301.0
# 20     20230927       20200824    36  MASCULINO         140136.0
# 21     20230927       20200718    20   FEMENINO          50107.0
# 22     20230927       20200716    22  MASCULINO          80519.0
# 23     20230927       20200715    33  MASCULINO          80101.0
# 24     20230927       20200830    41  MASCULINO         140131.0
# 25     20230927       20200830    56  MASCULINO          60101.0
# 26     20230927       20200828    44   FEMENINO         120506.0
# 27     20230927       20200724    44   FEMENINO         100101.0
# 28     20230927       20200724    44  MASCULINO         240105.0
# 29     20230927       20200724    26  MASCULINO         240102.0
# 30     20230927       20200731    59   FEMENINO          71303.0
# 31     20230927       20200731    21  MASCULINO         230101.0
# 32     20230927       20200730    57  MASCULINO         100101.0
# 33     20230927       20200901    43  MASCULINO          60101.0
# 34     20230927       20200901    23   FEMENINO         140130.0
# 35     20230927       20200901    50  MASCULINO          60202.0
# 36     20230927       20200715    22  MASCULINO          80201.0
# 37     20230927       20200717    47   FEMENINO          60801.0
# 38     20230927       20200717    40  MASCULINO         220101.0
# 39     20230927       20200717    44  MASCULINO         250107.0
# 40     20230927       20200717    33   FEMENINO         240101.0
# 41     20230927       20200731    59  MASCULINO         140101.0
# 42     20230927       20200730    46   FEMENINO          21301.0
# 43     20230927       20200731    45   FEMENINO          50107.0
# 44     20230927       20200718    31  MASCULINO         100304.0
# 45     20230927       20200714    58  MASCULINO         220112.0
# 46     20230927       20200714    37   FEMENINO         100110.0
# 47     20230927       20200713    37   FEMENINO         100101.0
# 48     20230927       20200718    34  MASCULINO          40101.0
# 49     20230927       20200718    55  MASCULINO          40101.0
#
#    DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE       DISTRITO_PACIENTE  \
# 0                   LIMA               LIMA  SAN JUAN DE LURIGANCHO
# 1                UCAYALI   CORONEL PORTILLO              CAMPOVERDE
# 2                   LIMA               LIMA             JESUS MARIA
# 3                 CALLAO             CALLAO              VENTANILLA
# 4                   LIMA               LIMA               SAN BORJA
# 5               AREQUIPA           AREQUIPA           JACOBO HUNTER
# 6               AREQUIPA           AREQUIPA          CERRO COLORADO
# 7           HUANCAVELICA           ANGARAES             CCOCHACCASA
# 8           HUANCAVELICA           ANGARAES                ANCHONGA
# 9                 TUMBES             TUMBES                 LA CRUZ
# 10                TUMBES          ZARUMILLA            AGUAS VERDES
# 11                   ICA                ICA             LOS AQUIJES
# 12                 JUNIN            CHUPACA                 CHUPACA
# 13                CALLAO             CALLAO                  CALLAO
# 14                  LIMA               LIMA                    LIMA
# 15                  LIMA               LIMA              CHORRILLOS
# 16             CAJAMARCA         SAN MARCOS            PEDRO GALVEZ
# 17             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 18                 JUNIN           HUANCAYO                EL TAMBO
# 19          HUANCAVELICA           ANGARAES                  LIRCAY
# 20                  LIMA               LIMA  SAN JUAN DE MIRAFLORES
# 21              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 22          HUANCAVELICA           TAYACAJA              SALCABAMBA
# 23          HUANCAVELICA       HUANCAVELICA            HUANCAVELICA
# 24                  LIMA               LIMA               SURQUILLO
# 25             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 26           LA LIBERTAD          PACASMAYO               PACASMAYO
# 27                   ICA                ICA                     ICA
# 28                CALLAO             CALLAO                LA PERLA
# 29                CALLAO             CALLAO              BELLAVISTA
# 30                 CUSCO           URUBAMBA            HUAYLLABAMBA
# 31                TUMBES             TUMBES                  TUMBES
# 32                   ICA                ICA                     ICA
# 33             CAJAMARCA          CAJAMARCA               CAJAMARCA
# 34                  LIMA               LIMA       SANTIAGO DE SURCO
# 35             CAJAMARCA          CAJABAMBA                CACHACHI
# 36          HUANCAVELICA           ACOBAMBA                ACOBAMBA
# 37             CAJAMARCA               JAEN                    JAEN
# 38                 TACNA              TACNA                   TACNA
# 39               UCAYALI   CORONEL PORTILLO                MANANTAY
# 40                CALLAO             CALLAO                  CALLAO
# 41                  LIMA               LIMA                    LIMA
# 42                ANCASH              SANTA                CHIMBOTE
# 43              AYACUCHO           HUAMANGA       SAN JUAN BAUTISTA
# 44                   ICA              NAZCA                 MARCONA
# 45                 TACNA              TACNA            CIUDAD NUEVA
# 46                   ICA                ICA             SUBTANJALLA
# 47                   ICA                ICA                     ICA
# 48              AREQUIPA           AREQUIPA                AREQUIPA
# 49              AREQUIPA           AREQUIPA                AREQUIPA
#
#    DEPARTAMENTO_MUESTRA        PROVINCIA_MUESTRA  \
# 0                  LIMA                     LIMA
# 1                  LIMA                     LIMA
# 2                  LIMA                     LIMA
# 3                  LIMA                     LIMA
# 4                  LIMA                     LIMA
# 5                  LIMA                     LIMA
# 6                  LIMA                     LIMA
# 7                  LIMA                     LIMA
# 8                  LIMA                     LIMA
# 9                TUMBES                   TUMBES
# 10               TUMBES                   TUMBES
# 11                  ICA                      ICA
# 12                JUNIN                 HUANCAYO
# 13                 LIMA                     LIMA
# 14                 LIMA                   HUAURA
# 15                 LIMA                     LIMA
# 16                 LIMA                     LIMA
# 17                 LIMA                     LIMA
# 18                 LIMA                     LIMA
# 19                 LIMA                     LIMA
# 20                 LIMA                     LIMA
# 21             AYACUCHO                 HUAMANGA
# 22         HUANCAVELICA             HUANCAVELICA
# 23         HUANCAVELICA             HUANCAVELICA
# 24                 LIMA                     LIMA
# 25                 LIMA                     LIMA
# 26                 LIMA                     LIMA
# 27                  ICA                      ICA
# 28               CALLAO  PROV. CONST. DEL CALLAO
# 29               CALLAO  PROV. CONST. DEL CALLAO
# 30                CUSCO                    CUSCO
# 31               TUMBES                   TUMBES
# 32                  ICA                      ICA
# 33                 LIMA                     LIMA
# 34                 LIMA                     LIMA
# 35                 LIMA                     LIMA
# 36         HUANCAVELICA                 ACOBAMBA
# 37            CAJAMARCA                     JAEN
# 38                TACNA                    TACNA
# 39              UCAYALI         CORONEL PORTILLO
# 40                 PUNO                     PUNO
# 41               CALLAO  PROV. CONST. DEL CALLAO
# 42               ANCASH                   HUARAZ
# 43             AYACUCHO                 HUAMANGA
# 44                 LIMA                     LIMA
# 45                TACNA                    TACNA
# 46                  ICA                      ICA
# 47                  ICA                      ICA
# 48                 LIMA                     LIMA
# 49                 LIMA                     LIMA
#
#                         DISTRITO_MUESTRA               TIPO_MUESTRA RESULTADO
# 0                              SAN BORJA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 1                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 2                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 3                            JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 4                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 5                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 6                      MAGDALENA DEL MAR  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 7                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 8                      SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 9                                 TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 10                                TUMBES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 11                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 12                              HUANCAYO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 13                SAN JUAN DE LURIGANCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 14                                HUACHO  HISOPADO NASAL Y FARINGEO  POSITIVO
# 15                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 16                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 17                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 18                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 19                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 20                     SANTIAGO DE SURCO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 21                     SAN JUAN BAUTISTA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 22                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 23                          HUANCAVELICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 24                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 25                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 26                            MIRAFLORES  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 27                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 28                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 29                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 30                         SAN SEBASTIAN  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 31                                TUMBES  HISOPADO NASAL Y FARINGEO  POSITIVO
# 32                                   ICA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 33                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 34                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 35                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 36                               PAUCARA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 37                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 38  CORONEL GREGORIO ALBARRACIN LANCHIPA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 39                           YARINACOCHA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 40                                  PUNO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 41                            BELLAVISTA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 42                                HUARAZ  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 43                              AYACUCHO  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 44                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 45                          CIUDAD NUEVA  HISOPADO NASAL Y FARINGEO  NEGATIVO
# 46                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 47                                   ICA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 48                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  POSITIVO
# 49                           JESUS MARIA  HISOPADO NASAL Y FARINGEO  NEGATIVO

# %%
import datetime as dt

# Convertir la columna 'FECHA_MUESTRA' a formato datetime
df['FECHA_MUESTRA'] = pd.to_datetime(df['FECHA_MUESTRA'], format='%Y%m%d')

# Función para determinar la estación del año en el hemisferio sur
def get_season(date):
    year = date.year
    seasons = {
        'Verano': (dt.date(year, 12, 21), dt.date(year + 1, 3, 20)),
        'Otoño': (dt.date(year, 3, 21), dt.date(year, 6, 20)),
        'Invierno': (dt.date(year, 6, 21), dt.date(year, 9, 22)),
        'Primavera': (dt.date(year, 9, 23), dt.date(year, 12, 20)),
    }
    if seasons['Verano'][0] <= date <= seasons['Verano'][1]:
        return 'Verano'
    elif seasons['Otoño'][0] <= date <= seasons['Otoño'][1]:
        return 'Otoño'
    elif seasons['Invierno'][0] <= date <= seasons['Invierno'][1]:
        return 'Invierno'
    else:
        return 'Primavera'

# Aplicar la función a la columna 'FECHA_MUESTRA'
df['ESTACION'] = df['FECHA_MUESTRA'].apply(lambda x: get_season(x.date()))

df[['FECHA_MUESTRA', 'ESTACION']].head(100)
# Out:
#    FECHA_MUESTRA   ESTACION
# 0     2020-07-24   Invierno
# 1     2020-09-01   Invierno
# 2     2020-09-01   Invierno
# 3     2020-09-01   Invierno
# 4     2020-08-26   Invierno
# ..           ...        ...
# 95    2020-09-14   Invierno
# 96    2020-09-14   Invierno
# 97    2020-09-24  Primavera
# 98    2020-09-24  Primavera
# 99    2020-09-24  Primavera
#
# [100 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# Codificar el resultado de la prueba
label_encoder = LabelEncoder()
df['RESULTADO_CODIFICADO'] = label_encoder.fit_transform(df['RESULTADO'])

# Crear variables dummy para las estaciones del año
df_dummies = pd.get_dummies(df['ESTACION'], drop_first=True)

# Unir las dummies al DataFrame original
df = pd.concat([df, df_dummies], axis=1)

# Variables independientes y dependientes
X = df_dummies
y = df['RESULTADO_CODIFICADO']

# Crear y entrenar el modelo de regresión lineal
model = LinearRegression()
model.fit(X, y)

# Ver los coeficientes del modelo
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coeficiente'])
print(coefficients)
# Out:
#            Coeficiente
# Otoño        -0.038759
# Primavera    -0.112921
# Verano       -0.068370

# %%
df.head(100)
# Out:
#     FECHA_CORTE FECHA_MUESTRA  EDAD       SEXO  UBIGEO_PACIENTE  \
# 0      20230927    2020-07-24    26   FEMENINO         140137.0
# 1      20230927    2020-09-01    27  MASCULINO         250104.0
# 2      20230927    2020-09-01    33  MASCULINO         140133.0
# 3      20230927    2020-09-01    46  MASCULINO         240106.0
# 4      20230927    2020-08-26    39  MASCULINO         140140.0
# ..          ...           ...   ...        ...              ...
# 95     20230927    2020-09-14    77  MASCULINO         140130.0
# 96     20230927    2020-09-14    24  MASCULINO          20325.0
# 97     20230927    2020-09-24    27   FEMENINO         170101.0
# 98     20230927    2020-09-24    36  MASCULINO          40119.0
# 99     20230927    2020-09-24    53  MASCULINO          40109.0
#
#    DEPARTAMENTO_PACIENTE PROVINCIA_PACIENTE       DISTRITO_PACIENTE  \
# 0                   LIMA               LIMA  SAN JUAN DE LURIGANCHO
# 1                UCAYALI   CORONEL PORTILLO              CAMPOVERDE
# 2                   LIMA               LIMA             JESUS MARIA
# 3                 CALLAO             CALLAO              VENTANILLA
# 4                   LIMA               LIMA               SAN BORJA
# ..                   ...                ...                     ...
# 95                  LIMA               LIMA       SANTIAGO DE SURCO
# 96                ANCASH          BOLOGNESI               HUALLANCA
# 97              MOQUEGUA     MARISCAL NIETO                MOQUEGUA
# 98              AREQUIPA           AREQUIPA                SOCABAYA
# 99              AREQUIPA           AREQUIPA              PAUCARPATA
#
#    DEPARTAMENTO_MUESTRA PROVINCIA_MUESTRA   DISTRITO_MUESTRA  \
# 0                  LIMA              LIMA          SAN BORJA
# 1                  LIMA              LIMA        JESUS MARIA
# 2                  LIMA              LIMA        JESUS MARIA
# 3                  LIMA              LIMA        JESUS MARIA
# 4                  LIMA              LIMA  MAGDALENA DEL MAR
# ..                  ...               ...                ...
# 95                 LIMA              LIMA              LINCE
# 96                 LIMA              LIMA              LINCE
# 97             AREQUIPA          AREQUIPA     CERRO COLORADO
# 98             AREQUIPA          AREQUIPA     CERRO COLORADO
# 99             AREQUIPA          AREQUIPA     CERRO COLORADO
#
#                  TIPO_MUESTRA RESULTADO   ESTACION  RESULTADO_CODIFICADO  \
# 0   HISOPADO NASAL Y FARINGEO  NEGATIVO   Invierno                     0
# 1   HISOPADO NASAL Y FARINGEO  NEGATIVO   Invierno                     0
# 2   HISOPADO NASAL Y FARINGEO  NEGATIVO   Invierno                     0
# 3   HISOPADO NASAL Y FARINGEO  NEGATIVO   Invierno                     0
# 4   HISOPADO NASAL Y FARINGEO  NEGATIVO   Invierno                     0
# ..                        ...       ...        ...                   ...
# 95  HISOPADO NASAL Y FARINGEO  POSITIVO   Invierno                     1
# 96  HISOPADO NASAL Y FARINGEO  NEGATIVO   Invierno                     0
# 97  HISOPADO NASAL Y FARINGEO  NEGATIVO  Primavera                     0
# 98  HISOPADO NASAL Y FARINGEO  NEGATIVO  Primavera                     0
# 99  HISOPADO NASAL Y FARINGEO  NEGATIVO  Primavera                     0
#
#     Otoño  Primavera  Verano
# 0   False      False   False
# 1   False      False   False
# 2   False      False   False
# 3   False      False   False
# 4   False      False   False
# ..    ...        ...     ...
# 95  False      False   False
# 96  False      False   False
# 97  False       True   False
# 98  False       True   False
# 99  False       True   False
#
# [100 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar estilo de los gráficos
sns.set(style="whitegrid")

# Contar la cantidad de pruebas por estación
pruebas_por_estacion = df['ESTACION'].value_counts()

# Crear una gráfica de barras para visualizar la distribución de las pruebas por estación
plt.figure(figsize=(10, 6))
sns.barplot(x=pruebas_por_estacion.index, y=pruebas_por_estacion.values, palette='viridis')
plt.title('Distribución de las Pruebas por Estación')
plt.xlabel('Estación')
plt.ylabel('Cantidad de Pruebas')
plt.show()
# Out:
# <ipython-input-25-812e9a026b53>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pruebas_por_estacion.index, y=pruebas_por_estacion.values, palette='viridis')

# %%
# Crear una gráfica de barras para visualizar los coeficientes de la regresión
plt.figure(figsize=(10, 6))
sns.barplot(x=coefficients.index, y=coefficients['Coeficiente'], palette='viridis')
plt.title('Coeficientes de la Regresión Lineal por Estación')
plt.xlabel('Estación')
plt.ylabel('Coeficiente')
plt.show()
# Out:
# <ipython-input-26-76e8410a783f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=coefficients.index, y=coefficients['Coeficiente'], palette='viridis')

# %%
# Descripción estadística de las columnas numéricas
print(df.describe())

# Análisis de las frecuencias de las categorías
print(df['SEXO'].value_counts())
print(df['RESULTADO'].value_counts())
print(df['DEPARTAMENTO_PACIENTE'].value_counts())

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>¿Qué es Colaboratory?</h2>
# </div>
#
# Colab, también conocido como "Colaboratory", te permite programar y ejecutar Python en tu navegador con las siguientes ventajas:
# - No requiere configuración
# - Acceso a GPUs sin coste adicional
# - Permite compartir contenido fácilmente
#
# Colab puede facilitar tu trabajo, ya seas <strong>estudiante</strong>, <strong>científico de datos</strong> o <strong>investigador de IA</strong>. No te pierdas el vídeo de <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introducción a Colab</a> para obtener más información. O simplemente empieza con los pasos descritos más abajo.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Primeros pasos</strong>
# </div>
#
# El documento que estás leyendo no es una página web estática, sino un entorno interactivo denominado <strong>cuaderno de Colab</strong> que te permite escribir y ejecutar código.
#
# Por ejemplo, a continuación se muestra una <strong>celda de código</strong> con una breve secuencia de comandos de Python que calcula un valor, lo almacena en una variable e imprime el resultado:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Si quieres ejecutar el código de la celda anterior, haz clic para seleccionarlo y pulsa el botón de reproducir situado a la izquierda del código o usa la combinación de teclas "Comando/Ctrl + Intro". Para editar el código, solo tienes que hacer clic en la celda.
#
# Las variables que definas en una celda se pueden usar después en otras celdas:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Los cuadernos de Colab te permiten combinar <strong>código ejecutable</strong> y <strong>texto enriquecido</strong> en un mismo documento, además de <strong>imágenes</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> y mucho más. Los cuadernos que creas en Colab se almacenan en tu cuenta de Google Drive. Puedes compartir tus cuadernos de Colab fácilmente con compañeros de trabajo o amigos, lo que les permite comentarlos o incluso editarlos. Consulta más información en <a href="/notebooks/basic_features_overview.ipynb">Información general sobre Colab</a>. Para crear un cuaderno de Colab, puedes usar el menú Archivo que aparece arriba o bien acceder al enlace para <a href="http://colab.research.google.com#create=true">crear un cuaderno de Colab</a>.
#
# Los cuadernos de Colab son cuadernos de Jupyter alojados en Colab. Para obtener más información sobre el proyecto Jupyter, visita <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Ciencia de datos
# </div>
#
# Con Colab, puedes aprovechar toda la potencia de las bibliotecas más populares de Python para analizar y visualizar datos. La celda de código de abajo utiliza <strong>NumPy</strong> para generar datos aleatorios y <strong>Matplotlib</strong> para visualizarlos. Para editar el código, solo tienes que hacer clic en la celda.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Puedes importar tus propios datos a los cuadernos de Colab desde tu cuenta de Google Drive, incluidas las hojas de cálculo, y también desde GitHub y muchas fuentes más. Para obtener más información sobre cómo importar datos y cómo se puede usar Colab en la ciencia de datos, consulta los enlaces que aparecen en la sección <a href="#working-with-data">Trabajar con datos</a> más abajo.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Aprendizaje automático
# </div>
#
# Con Colab, puedes importar un conjunto de datos de imágenes, entrenar un clasificador de imágenes con dicho conjunto de datos y evaluar el modelo con tan solo usar unas <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">pocas líneas de código</a>. Los cuadernos de Colab ejecutan código en los servidores en la nube de Google, lo que te permite aprovechar la potencia del hardware de Google, incluidas las <a href="#using-accelerated-hardware">GPU y TPU</a>, independientemente de la potencia de tu equipo. Lo único que necesitas es un navegador.

# %% [markdown]
# Colab es una herramienta muy utilizada en la comunidad de aprendizaje automático. Estos son algunos ejemplos de las aplicaciones que tiene Colab:
# - Dar los primeros pasos con TensorFlow
# - Desarrollar y entrenar redes neuronales
# - Experimentar con TPUs
# - Divulgar datos de investigación sobre IA
# - Crear tutoriales
#
# Para ver cuadernos de Colab que demuestran las aplicaciones del aprendizaje automático, consulta los <a href="#machine-learning-examples">ejemplos de aprendizaje automático</a> de abajo.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Más recursos
#
# ### Trabajar con cuadernos en Colab
#
# </div>
#
# - [Información general sobre Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guía de Markdown](/notebooks/markdown_guide.ipynb)
# - [Importar bibliotecas e instalar dependencias](/notebooks/snippets/importing_libraries.ipynb)
# - [Guardar y cargar cuadernos en GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Formularios interactivos](/notebooks/forms.ipynb)
# - [Widgets interactivos](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Trabajar con datos
# </div>
#
# - [Cargar datos: Drive, Hojas de cálculo y Google Cloud Storage](/notebooks/io.ipynb)
# - [Gráficos: visualización de datos](/notebooks/charts.ipynb)
# - [Primeros pasos con BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Curso intensivo de aprendizaje automático
#
# <div>
#
# A continuación, se muestran algunos cuadernos del curso online de Google sobre aprendizaje automático. Para obtener más información, consulta el <a href="https://developers.google.com/machine-learning/crash-course/">sitio web del curso completo</a>.
# - [Introducción a Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Regresión lineal con tf.keras usando datos sintéticos](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Uso de hardware acelerado
# </div>
#
# - [TensorFlow con GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow con TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Ejemplos destacados
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">Reemplaza voces con NeMo</a>: usa NeMo, el kit de herramientas de IA conversacional de Nvidia, para sustituir una voz de un fragmento de audio por otra generada por ordenador.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Reentrenamiento de un clasificador de imágenes</a>: crea un modelo de Keras sobre un clasificador de imágenes preparado previamente para que distinga flores.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Clasificación de textos</a>: clasifica las reseñas de películas de IMDb en <em>positivas</em> o <em>negativas</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Transferencia de estilo</a>: utiliza el aprendizaje profundo para transferir el estilo de una imagen a otra.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Codificador universal de frases multilingüe para preguntas y respuestas</a>: utiliza un modelo de aprendizaje automático para contestar preguntas con el conjunto de datos SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Interpolación de vídeo</a>: predice lo que ocurre entre el primer y el último fotograma de un vídeo.
